# %%
import math

# here is an example use of the while statement
# which is used for finding the root of a polynomial 
# which is known to lie within a certain interval.
# a is the lower value of the range
# b is the upper value of the range
eps=0.0000001
inf=9.9e30
a = 0.0
fa = -inf
b = 4.0
fb = inf
test=1.0
# Out:
# 0.0 4.0 2.0 2.0 -1.0 -9.9e+30
# 2.0 4.0 3.0 3.0 16.0 -1.0
# 2.0 3.0 2.5 2.5 5.625 -1.0
# 2.0 2.5 2.25 2.25 1.890625 -1.0
# 2.0 2.25 2.125 2.125 0.345703125 -1.0
# 2.0 2.125 2.0625 2.0625 -0.351318359375 -1.0
# 2.0625 2.125 2.09375 2.09375 -0.00894165039062 -0.351318359375
# 2.09375 2.125 2.109375 2.109375 0.166835784912 -0.00894165039062
# 2.09375 2.109375 2.1015625 2.1015625 0.0785622596741 -0.00894165039062
# 2.09375 2.1015625 2.09765625 2.09765625 0.034714281559 -0.00894165039062
# 2.09375 2.09765625 2.095703125 2.095703125 0.0128623321652 -0.00894165039062
# 2.09375 2.095703125 2.0947265625 2.0947265625 0.00195434782654 -0.00894165039062
# 2.09375 2.0947265625 2.09423828125 2.09423828125 -0.00349514919799 -0.00894165039062
# 2.09423828125 2.0947265625 2.09448242188 2.09448242188 -0.000770775208366 -0.00349514919799
# 2.09448242188 2.0947265625 2.09460449219 2.09460449219 0.00059169267297 -0.000770775208366
# 2.09448242188 2.09460449219 2.09454345703 2.09454345703 -8.95646760455e-05 -0.000770775208366
# 2.09454345703 2.09460449219 2.09457397461 2.09457397461 0.00025105814629 -8.95646760455e-05
# 2.09454345703 2.09457397461 2.09455871582 2.09455871582 8.07452720899e-05 -8.95646760455e-05
# 2.09454345703 2.09455871582 2.09455108643 2.09455108643 -4.41006773499e-06 -8.95646760455e-05
# 2.09455108643 2.09455871582 2.09455490112 2.09455490112 3.81675107377e-05 -4.41006773499e-06
# 2.09455108643 2.09455490112 2.09455299377 2.09455299377 1.68786986414e-05 -4.41006773499e-06
# 2.09455108643 2.09455299377 2.0945520401 2.0945520401 6.23430973867e-06 -4.41006773499e-06
# 2.09455108643 2.0945520401 2.09455156326 2.09455156326 9.1211957276e-07 -4.41006773499e-06
# 2.09455108643 2.09455156326 2.09455132484 2.09455132484 -1.74897443728e-06 -4.41006773499e-06
# 2.09455132484 2.09455156326 2.09455144405 2.09455144405 -4.18427521964e-07 -1.74897443728e-06
#  The root is : 2.09455144405

# %% [markdown]
# (E=mc^2)，$$x_{1,2} = \sum _{n=1}^{n=\infty}\frac{-b \pm \sqrt{b^2-4ac}}{2b}.$$

# %%
while abs(b-a)>(eps*b):
  x = (a+b)/2.0
  fx = math.pow(x,3)-2*x-5
  print a,b,(a+b)/2,x,fx,fa
  if math.copysign(test,fx) == math.copysign(test,fa):
    a = x
    fa = fx
  else:
    b = x
    fb = fx

# %%
print ' The root is :',x
